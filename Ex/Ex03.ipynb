# %%
exam=[]
for line in f:
  exam.append()

# %%
exam = [[int(x) for x in row] for row in exam]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2418265002.py in <cell line: 0>()
# ----> 1 exam = [[int(x) for x in row] for row in exam]
#
# NameError: name 'exam' is not defined

# %%
exam=[[int(x) for x in row] for row in exam]

# %%
math= [row[2] for row in exam]
print(math)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-179021123.py in <cell line: 0>()
# ----> 1 math= [row[2] for row in exam]
#       2 print(math)
#
# NameError: name 'exam' is not defined

# %%
max(math)
min(math)
sum(math)/len(math)
eng=[row[3]for x in exam]
print(eng)
cls1=[row[2]for row in exam if row[2]==1]
for cls in range(1,6):
  mcls=[row[2] for x in exam if row[2]==cls]
  mean=sum(mcls)/len(mcls)
  print({반}{평균})
def subject_mean_by_class(cls, subject):
    score = []

    for student in exam2:
        if student.cls == cls:
            if subject == 'math':
                score.append(student.math)
            elif subject == 'english':
                score.append(student.english)
            elif subject == 'science':
                score.append(student.science)

    return sum(score) / len(score)
