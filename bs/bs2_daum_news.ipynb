# %% [markdown]
# * 다음 메인 페이지에서 검색어 입력하고 검색
# * 검색 결과 페이지에서 뉴스 섹션을 클릭(선택)
# * 뉴스 제목과 링크를 크롤링

# %%
# 웹 서버에 요청(request)을 보내고 응답(response)을 받는 기능을 가지고 있는 모듈
import requests

# HTML 분석(parsing)
from bs4 import BeautifulSoup

# %%
# 요청(request)을 보낼 주소(URL)
url1= 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4'

# %%
# 요청주소(URL)로 GET 방식의 요청을 보내고 응답을 받음.
response=requests.get(url1)
print(response) # 200 -응답성공
# Out:
# <Response [200]>

# %%
# 응답(response)에 포함된 HTML 코드(문자열)을 추출.
html =response.text.strip()

# %%
print(html[:200]) # HTML 문자열에서 첫 200글자
# Out:
# <!doctype html>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="ko">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta http-equiv="content-Type" content="text/html;charset=utf-8" />
# <meta h

# %%
print(html[-200:]) # HTML 문자열에서 마지막 200글자
# Out:
# \/search\/statics\/common\/js\/fe\/search-library-workspace\/virtual-keyboard\/1.3.0\/main.js",
# crossOrigin: true,
# done: function() {
# virtualKeyboard({
# DA: 'BFJ'
# })
# }
# });
# });
# </script>
# </body>
# </html>

# %%
# HTML 분석하는 BeautifulSoup 객체 생성
bs = BeautifulSoup(markup=html, features='html5lib')

# %%
selector ='ul.c-list-basic div.item-title a'

# %%
elements =bs.select(selector)

# %%
for x in elements:
  print(x.text.strip())
  print(x.get('href'))
# Out:
# SOOP, 설 연휴 콘텐츠 한자리에…‘2026 설 특집 페이지’ 오픈
# http://v.daum.net/v/20260210171342384
# 설 연휴, 인천 시민 달라지는 점은?
# http://v.daum.net/v/20260210175522371
# 웨이브, 설 연휴 추천작 공개
# http://v.daum.net/v/20260211094221584
# 물가·의료·교통·관광까지…경기도 설 연휴 종합대책
# http://v.daum.net/v/20260211094326646
# 설 연휴 해외여행 '폭발'…단거리·프리미엄 여행 인기
# http://v.daum.net/v/20260211093447164
# 트립닷컴 “설 연휴 여행, 더 오래 머물고 더 멀리 떠난다”
# http://v.daum.net/v/20260211063303469
# 음성군, 설 명절 종합대책 추진, 안전하고 따뜻한 설 연휴 만든다
# http://v.daum.net/v/20260211111427076
# "설 연휴 고속도, 귀성은 13일·귀경은 17일 가장 혼잡"
# http://v.daum.net/v/20260211101507469
# 경기도, 민생·안전·보건·문화 등 생활전반 '설 연휴 종합대책' 시행
# http://v.daum.net/v/20260211100323758
# KOMSA, 설 연휴 특별교통 대책…여객선 운항 8.7% 확대
# http://v.daum.net/v/20260211110324284

# %%
url2='https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4&p=2'

# %%
print(url1)
print(url2)
# Out:
# https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4
# https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4&p=2

# %% [markdown]
# 뉴스 검색 결과를 1페이지부터 5페이지까지 출력

# %%
for page in range(1,6):
  print(f'\n**** page {page} ****')
  url=f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4&p={page}'
  response=requests.get(url)
  print(response)

  html=response.text.strip()
  bs=BeautifulSoup(markup=html,features='html5lib')
  selector ='ul.c-list-basic div.item-title a'
  elements = bs.select(selector)

  for x in elements:
    print(x.get('href'))
    print(x.text)
# Out:
# **** page 1 ****
# <Response [200]>
# http://v.daum.net/v/20260211094326646
#  물가·의료·교통·관광까지…경기도 설 연휴 종합대책
# http://v.daum.net/v/20260210171342384
#  SOOP, 설 연휴 콘텐츠 한자리에…‘2026 설 특집 페이지’ 오픈
# http://v.daum.net/v/20260211120545603
#  행안부 "설 연휴, 교통사고와 산불 조심하세요"
# http://v.daum.net/v/20260210175522371
#  설 연휴, 인천 시민 달라지는 점은?
# http://v.daum.net/v/20260211063303469
#  트립닷컴 “설 연휴 여행, 더 오래 머물고 더 멀리 떠난다”
# http://v.daum.net/v/20260211093447164
#  설 연휴 해외여행 '폭발'…단거리·프리미엄 여행 인기
# http://v.daum.net/v/20260210181529206
#  설 연휴 2천800만명 ‘민족 대이동’
# http://v.daum.net/v/20260211101507469
#  "설 연휴 고속도, 귀성은 13일·귀경은 17일 가장 혼잡"
# http://v.daum.net/v/20260211111427076
#  음성군, 설 명절 종합대책 추진, 안전하고 따뜻한 설 연휴 만든다
# http://v.daum.net/v/20260211100323758
#  경기도, 민생·안전·보건·문화 등 생활전반 '설 연휴 종합대책' 시행
#
# **** page 2 ****
# <Response [200]>
# http://v.daum.net/v/20260211090025240
#  "연휴 전 점검하세요"…토스인슈어런스, 설연휴 보험 체크포인트 안내
# http://v.daum.net/v/20260211082620101
#  김포시, 설 연휴 종합대책 추진…7개 분야별 대책반 구성
# ...

# %%
for page in range(1,6):
  print(f'\n**** page {page} ****')
  url=f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%84%A4+%EC%97%B0%ED%9C%B4&p={page}'
  response=requests.get(url)
  print(response)

  html=response.text.strip()
  bs=BeautifulSoup(markup=html,features='html5lib')
  selector1 ='ul.c-list-basic div.item-title a' # 기사 제목
  selector2 ='ul.c-list-basic div.item-contents a' # 기사 내용 일부
  elements1 = bs.select(selector1)
  elements2 = bs.select(selector2)
  for title, content in zip(elements1,elements2):

    print(title.get('href'))
    print(title.text)
    print(content.text)
# Out:
# **** page 1 ****
# <Response [200]>
# http://v.daum.net/v/20260211094326646
#  물가·의료·교통·관광까지…경기도 설 연휴 종합대책
#  경기도 설 연휴 종합대책 홍보물 /경기도 [더팩트ㅣ수원=이승호 기자] 경기도가 11일 민생안정, 안전·보건, 문화·복지, 교통·편의 등 4개 분야, 20개 세부 항목이 담긴 '설 연휴 종합대책'을 발표했다. 분야별 주요 내용은 다음과 같다. ◆ 민생안정 도는 설 명절...
# http://v.daum.net/v/20260210171342384
#  SOOP, 설 연휴 콘텐츠 한자리에…‘2026 설 특집 페이지’ 오픈
#  최영우)은 설날 특집 콘텐츠를 한눈에 확인할 수 있는 ‘2026 설 특집 페이지’를 10일(화) 공개했다. 이번 특집 페이지에서는 설 연휴 기간 진행되는 스트리머 라이브 방송을 비롯해 시네티 콘텐츠, 이벤트 등 주요 콘텐츠 정보를 제공한다. 먼저 라이브 탭에서는...
# http://v.daum.net/v/20260211120545603
#  행안부 "설 연휴, 교통사고와 산불 조심하세요"
#  등으로 산에 갈 때는 산불 예방에 각별한 주의를 기울여 줄 것을 11일 당부했다. (사진=행정안전부) 최근 5년(2020~2024년)간 설 연휴 기간 발생한 교통사고를 분석한 결과, 연휴 중 하루 평균 340건의 교통사고가 발생했다. 설 전후로 교통사고 위험이 가장 높은...
# http://v.daum.net/v/20260210175522371
#  설 연휴, 인천 시민 달라지는 점은?
#  설 연휴 시장을 찾은 시민들 [사진 = 인천시] [앵커] 설 연휴를 앞두고 인천시가 민생을 중심으로 한 종합대책을 내놨습니다. 민자터널을 무료로 이용할 수 있고, 바가지 요금도 신고할 수 있습니다. 인천 시민들이 설 연휴 동안 체감할 변화들을 김예빈 기자가 정리...
# http://v.daum.net/v/20260211093447164
# ...

# %%
# 옵션에 일 주 개월 = 리스트로 주면된다
# 주소창 옵션변경 부분
# 셀레니움 툴확인
