# %%
# import src.my_util01.addition #addition 모듈을 임포트. 가져옴
#src.my_util01.addition  >>>  addition.py의 print(__name__)
#직접 실행된 파일만 __main__이다

import src.my_util01.addition as addition # import문에 별명 주기. 1번째방법

#from... import구문
from src.my_util01.subtraction import minus
#> src.my_util01.subtraction 모듈(파일)에서 함수 minus를 임포트.

# myutil2 패키지를 임포트
import src.myutil02 as util #init내에있는 임포트들의 모음


# def minuss(x):
#     return -x
# def pluss(x):
#     return x+1

#__name__변수: 모든 파이썬 모듈(*.py파일)이 가지고 있는 특별한 변수.
# (1) 현재 파일을 실행할 때는 '__main__' 문자열이 할당됨.
# (2) 다른 파일에서 import될 때는 (네임변수에) 파일(경로) 이름이 할당됨.
# (목적) 단독으로 실행할 코드와 import될 때 실행할 코드를 구분하기 위해서.
#       ㄹ
print(__name__) # >>> __main__



if __name__ == '__main__':
    print('하이') #문자열모양?
    # result= src.my_util01.addition.plus(2,3)
    result=addition.plus(5,8) # 1임포트후 함수호출
    print(result)

    result=minus(4,6) # 2 바로 함수 호출 함수이름겹치는거주의
    print(result)

    result=util.multiply(3,4)
    print(result)
    result=util.divide(4,2)# init내에 주석처리해버리면 사용불가
    print(result)
